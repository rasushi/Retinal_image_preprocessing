# %% [markdown]
# <a href="https://colab.research.google.com/github/rasushi/Retinal_image_preprocessing/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
